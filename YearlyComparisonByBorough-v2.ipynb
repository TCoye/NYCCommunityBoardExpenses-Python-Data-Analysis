# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.rand(6, 4),
                 index=['one', 'two', 'three', 'four', 'five', 'six'],
                 columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df
df.plot.bar()
plt.show()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# /home/nbuser/anaconda3_501/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/nbuser/anaconda3_501/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.944638  0.835014  0.787550  0.176626
# two    0.190364  0.290302  0.114584  0.453415
# three  0.485543  0.348688  0.476906  0.767318
# four   0.465004  0.342073  0.470417  0.590239
# five   0.303233  0.364831  0.555331  0.240469
# six    0.786192  0.552745  0.657067  0.890990

# %%
df = pd.read_pickle('Expense_Budget.p')
df
# Out:
#         Publication Date  Fiscal Year Agency Number  \
# 0               20160426         2017             2
# 1               20160426         2017             2
# 2               20160426         2017             2
# 3               20160426         2017             2
# 4               20160426         2017             2
# 5               20160426         2017             2
# 6               20160426         2017             2
# 7               20160426         2017             2
# 8               20160426         2017             2
# 9               20160426         2017             2
# 10              20160426         2017             2
# 11              20160426         2017             2
# 12              20160426         2017             2
# 13              20160426         2017             2
# 14              20160426         2017             2
# 15              20160426         2017             2
# 16              20160426         2017             2
# ...

# %%
df.columns
# Out:
# Index(['Publication Date', 'Fiscal Year', 'Agency Number', 'Agency Name',
#        'Unit Appropriation Number', 'Unit Appropriation Name',
#        'Budget Code Number', 'Budget Code Name', 'Object Class Number',
#        'Object Class Name', 'Object Code', 'Object Code Name',
#        'Intra-City Purchase Code', 'Responsibility Center Code',
#        'Responsibility Center Name',
#        'Personal Service/Other Than Personal Service Indicator',
#        'Financial Plan Savings Flag', 'Adopted Budget Amount',
#        'Current Modified Budget Amount', 'Financial Plan Amount',
#        'Adopted Budget Position', 'Current Modified Budget Position',
#        'Financial Plan Position', 'Adopted Budget - Number of Contracts',
#        'Current Modified Budget - Number of Contracts',
#        'Financial Plan - Number of Contracts'],
#       dtype='object')

# %%
df[['Fiscal Year', 'Agency Name', 'Adopted Budget Amount']]
# Out:
#         Fiscal Year                           Agency Name  \
# 0              2017                             MAYORALTY
# 1              2017                             MAYORALTY
# 2              2017                             MAYORALTY
# 3              2017                             MAYORALTY
# 4              2017                             MAYORALTY
# 5              2017                             MAYORALTY
# 6              2017                             MAYORALTY
# 7              2017                             MAYORALTY
# 8              2017                             MAYORALTY
# 9              2017                             MAYORALTY
# 10             2017                             MAYORALTY
# 11             2017                             MAYORALTY
# 12             2017                             MAYORALTY
# 13             2017                             MAYORALTY
# 14             2017                             MAYORALTY
# ...

# %%
grouped_df = df[['Adopted Budget Amount', 'Agency Name','Fiscal Year']].groupby(['Fiscal Year', 'Agency Name']).sum()
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#      Fiscal Year                           Agency Name  Adopted Budget Amount
# 0           2017         ADMIN FOR CHILDREN'S SERVICES           5.897844e+09
# 1           2017                   BOARD OF CORRECTION           5.074716e+06
# 2           2017                    BOARD OF ELECTIONS           2.805045e+08
# 3           2017          BOROUGH PRESIDENT - BROOKLYN           1.172747e+07
# 4           2017         BOROUGH PRESIDENT - MANHATTAN           9.427342e+06
# 5           2017            BOROUGH PRESIDENT - QUEENS           1.030966e+07
# 6           2017               BOROUGH PRESIDENT BRONX           1.129066e+07
# 7           2017       BOROUGH PRESIDENT STATEN ISLAND           8.665412e+06
# 8           2017              BRONX COMMUNITY BOARD #1           5.743820e+05
# 9           2017             BRONX COMMUNITY BOARD #10           6.085020e+05
# 10          2017             BRONX COMMUNITY BOARD #11           5.692620e+05
# ...

# %%
grouped_df_qcb= grouped_df[grouped_df['Agency Name'].str.contains("QUEENS COMMUNITY BOARD ")]

grouped_df_bcb= grouped_df[grouped_df['Agency Name'].str.contains("BROOKLYN COMMUNITY BOARD")]

grouped_df_sicb= grouped_df[grouped_df['Agency Name'].str.contains("STATEN ISLAND COMMUNITY BOARD")]

grouped_df_bxcb= grouped_df[grouped_df['Agency Name'].str.contains("BRONX COMMUNITY BOARD")]

grouped_df_mcb= grouped_df[grouped_df['Agency Name'].str.contains("MANHATTAN COMMUNITY BOARD")]

# %%
grouped_df_mcb['Adopted Budget Amount'].values.sum()
# Out:
# 33287659.0

# %%
grouped_df_qcb['Adopted Budget Amount'].values.sum()
# Out:
# 32315437.0

# %%
grouped_df_bcb['Adopted Budget Amount'].values.sum()
# Out:
# 40953399.0

# %%
grouped_df_sicb['Adopted Budget Amount'].values.sum()
# Out:
# 7330287.0

# %%
grouped_df_bxcb['Adopted Budget Amount'].values.sum()
# Out:
# 26338116.0

# %%
df = pd.DataFrame(np.random.rand(3,5),
                 index=[2017,2018,2019],
                 columns=pd.Index(['STATEN ISLAND COMMUNITY BOARD','BRONX COMMUNITY BOARD','BROOKLYN COMMUNITY BOARD', 'QUEENS COMMUNITY BOARD', 'MANHATTAN COMMUNITY BOARD'], name='Annual Spending By Borough'))
df
df.plot.bar()
plt.show()

# %%
df = pd.DataFrame(np.random.rand(5,1),
                 index=['STATEN ISLAND COMMUNITY BOARD','BRONX COMMUNITY BOARD','BROOKLYN COMMUNITY BOARD', 'QUEENS COMMUNITY BOARD', 'MANHATTAN COMMUNITY BOARD'],
                 columns=pd.Index([2017], name='Annual Spending By Borough'))
df
df.plot.bar()
plt.show()

# %%
df = pd.DataFrame(np.random.rand(3,5),
                 index=[2017,2018,2019],
                 columns=pd.Index(['STATEN ISLAND COMMUNITY BOARD','BRONX COMMUNITY BOARD','BROOKLYN COMMUNITY BOARD', 'QUEENS COMMUNITY BOARD', 'MANHATTAN COMMUNITY BOARD'], name='Annual Spending By Borough'))
df
df.plot.bar()
plt.show()

# %%
df = pd.read_pickle('Expense_Budget.p')
df

df2 = df[['Fiscal Year', 'Agency Name', 'Adopted Budget Amount']]
df2['Agency Name'] = df2['Agency Name'].apply(lambda x: 'QUEENS COMMUNITY BOARD' if 'QUEENS COMMUNITY BOARD' in x else x)
df2 [df2['Agency Name']== 'QUEENS COMMUNITY BOARD']
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         Fiscal Year             Agency Name  Adopted Budget Amount
# 2615           2017  QUEENS COMMUNITY BOARD                  200.0
# 2616           2017  QUEENS COMMUNITY BOARD                 2400.0
# 2617           2017  QUEENS COMMUNITY BOARD                    0.0
# 2618           2017  QUEENS COMMUNITY BOARD                  275.0
# 2619           2017  QUEENS COMMUNITY BOARD                 1500.0
# 2620           2017  QUEENS COMMUNITY BOARD                 1700.0
# 2621           2017  QUEENS COMMUNITY BOARD                 1890.0
# 2622           2017  QUEENS COMMUNITY BOARD                    0.0
# ...

# %%
df2['Agency Name'] = df2['Agency Name'].apply(lambda x: 'STATEN ISLAND COMMUNITY BOARD' if 'STATEN ISLAND COMMUNITY BOARD' in x else x)
df2 [df2['Agency Name']== 'STATEN ISLAND COMMUNITY BOARD']
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#         Fiscal Year                    Agency Name  Adopted Budget Amount
# 2741           2017  STATEN ISLAND COMMUNITY BOARD                    0.0
# 2742           2017  STATEN ISLAND COMMUNITY BOARD                  500.0
# 2743           2017  STATEN ISLAND COMMUNITY BOARD                 1850.0
# 2744           2017  STATEN ISLAND COMMUNITY BOARD                    0.0
# 2745           2017  STATEN ISLAND COMMUNITY BOARD                  300.0
# 2746           2017  STATEN ISLAND COMMUNITY BOARD                    0.0
# ...

# %%
df2['Agency Name'] = df2['Agency Name'].apply(lambda x: 'BRONX COMMUNITY BOARD' if 'BRONX COMMUNITY BOARD' in x else x)
df2 [df2['Agency Name']== 'BRONX COMMUNITY BOARD']
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#         Fiscal Year            Agency Name  Adopted Budget Amount
# 2581           2017  BRONX COMMUNITY BOARD                  999.0
# 2582           2017  BRONX COMMUNITY BOARD                  649.0
# 2583           2017  BRONX COMMUNITY BOARD                    0.0
# 2584           2017  BRONX COMMUNITY BOARD                  440.0
# 2585           2017  BRONX COMMUNITY BOARD                    0.0
# 2586           2017  BRONX COMMUNITY BOARD                    0.0
# 2587           2017  BRONX COMMUNITY BOARD                    0.0
# ...

# %%
df2['Agency Name'] = df2['Agency Name'].apply(lambda x: 'BROOKLYN COMMUNITY BOARD' if 'BROOKLYN COMMUNITY BOARD' in x else x)
df2 [df2['Agency Name']== 'BROOKLYN COMMUNITY BOARD']
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#         Fiscal Year               Agency Name  Adopted Budget Amount
# 2663           2017  BROOKLYN COMMUNITY BOARD                   51.0
# 2664           2017  BROOKLYN COMMUNITY BOARD                  174.0
# 2665           2017  BROOKLYN COMMUNITY BOARD                   50.0
# 2666           2017  BROOKLYN COMMUNITY BOARD                   50.0
# 2667           2017  BROOKLYN COMMUNITY BOARD                  540.0
# 2668           2017  BROOKLYN COMMUNITY BOARD                  199.0
# 2670           2017  BROOKLYN COMMUNITY BOARD                  540.0
# ...

# %%
df2['Agency Name'] = df2['Agency Name'].apply(lambda x: 'MANHATTAN COMMUNITY BOARD' if 'MANHATTAN COMMUNITY BOARD' in x else x)
df2 [df2['Agency Name']== 'MANHATTAN COMMUNITY BOARD']
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#         Fiscal Year                Agency Name  Adopted Budget Amount
# 2555           2017  MANHATTAN COMMUNITY BOARD                    0.0
# 2556           2017  MANHATTAN COMMUNITY BOARD                    0.0
# 2557           2017  MANHATTAN COMMUNITY BOARD                    0.0
# 2558           2017  MANHATTAN COMMUNITY BOARD                 2500.0
# 2559           2017  MANHATTAN COMMUNITY BOARD                 1500.0
# 2560           2017  MANHATTAN COMMUNITY BOARD                    0.0
# 2561           2017  MANHATTAN COMMUNITY BOARD                    0.0
# ...

# %%
df3 =df2[(df2['Agency Name']== 'QUEENS COMMUNITY BOARD' )| (df2['Agency Name']== 'MANHATTAN COMMUNITY BOARD')| (df2['Agency Name']== 'BROOKLYN COMMUNITY BOARD')| (df2['Agency Name']== 'BRONX COMMUNITY BOARD')| (df2['Agency Name']== 'STATEN ISLAND COMMUNITY BOARD') ]

# %%
df3
# Out:
#         Fiscal Year                    Agency Name  Adopted Budget Amount
# 2555           2017      MANHATTAN COMMUNITY BOARD                    0.0
# 2556           2017      MANHATTAN COMMUNITY BOARD                    0.0
# 2557           2017      MANHATTAN COMMUNITY BOARD                    0.0
# 2558           2017      MANHATTAN COMMUNITY BOARD                 2500.0
# 2559           2017      MANHATTAN COMMUNITY BOARD                 1500.0
# 2560           2017      MANHATTAN COMMUNITY BOARD                    0.0
# 2561           2017      MANHATTAN COMMUNITY BOARD                    0.0
# 2562           2017      MANHATTAN COMMUNITY BOARD                    0.0
# 2563           2017      MANHATTAN COMMUNITY BOARD                    0.0
# 2564           2017      MANHATTAN COMMUNITY BOARD                    0.0
# 2565           2017      MANHATTAN COMMUNITY BOARD                  500.0
# 2566           2017      MANHATTAN COMMUNITY BOARD                    0.0
# ...

# %%
df4=df3.groupby(['Fiscal Year', 'Agency Name'])['Adopted Budget Amount'].sum()

# %%
df4
# Out:
# Fiscal Year  Agency Name
# 2017         BRONX COMMUNITY BOARD             6485148.0
#              BROOKLYN COMMUNITY BOARD         10085790.0
#              MANHATTAN COMMUNITY BOARD         7817158.0
#              QUEENS COMMUNITY BOARD            7954246.0
#              STATEN ISLAND COMMUNITY BOARD     1813266.0
# 2018         BRONX COMMUNITY BOARD             9894645.0
#              BROOKLYN COMMUNITY BOARD         15422949.0
#              MANHATTAN COMMUNITY BOARD        13111611.0
#              QUEENS COMMUNITY BOARD           12133023.0
#              STATEN ISLAND COMMUNITY BOARD     2764374.0
# 2019         BRONX COMMUNITY BOARD             9958323.0
#              BROOKLYN COMMUNITY BOARD         15444660.0
#              MANHATTAN COMMUNITY BOARD        12358890.0
#              QUEENS COMMUNITY BOARD           12228168.0
#              STATEN ISLAND COMMUNITY BOARD     2752647.0
# Name: Adopted Budget Amount, dtype: float64

# %%
df4 = df4.reset_index()
df4 = df4.set_index('Fiscal Year')

# %%
df5 = df4.reset_index()

# %%
df4.plot.bar()
plt.show()

# %%
df = pd.DataFrame({'key': ['foo', 'bar', 'baz'],
                  'A': [1, 2, 3],
                  'B': [4, 5, 6],
                  'C': [7, 8, 9]})

melted = pd.melt(df, ['key'])
melted
# Out:
#    key variable  value
# 0  foo        A      1
# 1  bar        A      2
# 2  baz        A      3
# 3  foo        B      4
# 4  bar        B      5
# 5  baz        B      6
# 6  foo        C      7
# 7  bar        C      8
# 8  baz        C      9

# %%
df5
# Out:
#     Fiscal Year                    Agency Name  Adopted Budget Amount
# 0          2017          BRONX COMMUNITY BOARD              6485148.0
# 1          2017       BROOKLYN COMMUNITY BOARD             10085790.0
# 2          2017      MANHATTAN COMMUNITY BOARD              7817158.0
# 3          2017         QUEENS COMMUNITY BOARD              7954246.0
# 4          2017  STATEN ISLAND COMMUNITY BOARD              1813266.0
# 5          2018          BRONX COMMUNITY BOARD              9894645.0
# 6          2018       BROOKLYN COMMUNITY BOARD             15422949.0
# 7          2018      MANHATTAN COMMUNITY BOARD             13111611.0
# 8          2018         QUEENS COMMUNITY BOARD             12133023.0
# 9          2018  STATEN ISLAND COMMUNITY BOARD              2764374.0
# 10         2019          BRONX COMMUNITY BOARD              9958323.0
# 11         2019       BROOKLYN COMMUNITY BOARD             15444660.0
# ...

# %%
reshaped = df5.pivot('Fiscal Year', 'Agency Name', 'Adopted Budget Amount')
reshaped
# Out:
# Agency Name  BRONX COMMUNITY BOARD  BROOKLYN COMMUNITY BOARD  \
# Fiscal Year
# 2017                     6485148.0                10085790.0
# 2018                     9894645.0                15422949.0
# 2019                     9958323.0                15444660.0
#
# Agency Name  MANHATTAN COMMUNITY BOARD  QUEENS COMMUNITY BOARD  \
# Fiscal Year
# 2017                         7817158.0               7954246.0
# 2018                        13111611.0              12133023.0
# 2019                        12358890.0              12228168.0
#
# Agency Name  STATEN ISLAND COMMUNITY BOARD
# Fiscal Year
# 2017                             1813266.0
# 2018                             2764374.0
# 2019                             2752647.0

# %%
reshaped.plot.bar()
plt.show()

# %%
#reshaped.plot.bar()
#plt.show()

reshaped = df5.pivot('Fiscal Year', 'Agency Name', 'Adopted Budget Amount')

import matplotlib as mpl
ax = reshaped.plot( kind='bar',  width=.5)
# ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
#           ncol=3, fancybox=True, shadow=True)


# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width, box.height])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
#ax.set_title('Adopted Budget Amount', fontsize= 10,position=(.50, 1)) # title of plot
axes = plt.gca()
#axes.set_ylim([])
plt.xticks(rotation=0)
title_string = "Adopted Budget Amount By Borough"
plt.suptitle(title_string, y=1.02, fontsize=14)
plt.tight_layout()
plt.savefig('img/pltmanhattan.png',dpi = 100,bbox_inches = 'tight')
plt.show()
